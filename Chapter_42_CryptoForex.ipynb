# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas_datareader as web
import pandas as pd

# %%
symbol = 'ETH-USD'
data = yf.Ticker(symbol)
data
# Out:
# yfinance.Ticker object <ETH-USD>

# %%
history = data.history(period='1d',start='2018-01-01',end='2020-10-30')
history
# Out:
#                                  Open         High         Low       Close  \
# Date
# 2018-01-01 00:00:00+00:00  755.757019   782.530029  742.004028  772.640991
# 2018-01-02 00:00:00+00:00  772.346008   914.830017  772.346008  884.443970
# 2018-01-03 00:00:00+00:00  886.000000   974.471008  868.450989  962.719971
# 2018-01-04 00:00:00+00:00  961.713013  1045.079956  946.085999  980.921997
# 2018-01-05 00:00:00+00:00  975.750000  1075.390015  956.325012  997.719971
# ...                               ...          ...         ...         ...
# 2020-10-25 00:00:00+00:00  412.457642   417.159210  405.350647  406.217773
# 2020-10-26 00:00:00+00:00  406.217987   411.279877  383.782898  393.888306
# 2020-10-27 00:00:00+00:00  393.888184   409.772858  390.608459  403.997040
# 2020-10-28 00:00:00+00:00  403.997101   408.964752  381.146332  388.650757
# 2020-10-29 00:00:00+00:00  388.651062   393.227692  381.288757  386.730103
#
# ...

# %%
plt.plot(history['Close'])

# %%
df = yf.download(['BTC-USD','ETH-USD'],period='1d',start='2018-01-01',end='2020-10-30')
df
# Out:
# [*********************100%%**********************]  2 of 2 completed
#                Adj Close                     Close                      High  \
#                  BTC-USD     ETH-USD       BTC-USD     ETH-USD       BTC-USD
# Date
# 2018-01-01  13657.200195  772.640991  13657.200195  772.640991  14112.200195
# 2018-01-02  14982.099609  884.443970  14982.099609  884.443970  15444.599609
# 2018-01-03  15201.000000  962.719971  15201.000000  962.719971  15572.799805
# 2018-01-04  15599.200195  980.921997  15599.200195  980.921997  15739.700195
# 2018-01-05  17429.500000  997.719971  17429.500000  997.719971  17705.199219
# ...                  ...         ...           ...         ...           ...
# 2020-10-25  13031.173828  406.217773  13031.173828  406.217773  13329.183594
# 2020-10-26  13075.248047  393.888306  13075.248047  393.888306  13225.297852
# 2020-10-27  13654.218750  403.997040  13654.218750  403.997040  13759.668945
# ...

# %%
import pandas_datareader as web

# %%
# df = web.DataReader('BTC-USD' , 'yahoo' ,start='2018-01-01' , end='2020-10-30')

# %%
df['Date'] = df.index
df = df.set_index(pd.DatetimeIndex(df['Date'].values))

plt.plot(df['Close'])
plt.show()

# %%
df = pd.read_csv('btc.csv',skiprows=1)
df
# Out:
#        Unix Timestamp              Date  Symbol      Open      High       Low  \
# 0        1.604473e+09  2020-11-04 07-AM  BTCUSD  13810.45  13813.81  13776.92
# 1        1.604470e+09  2020-11-04 06-AM  BTCUSD  13804.32  13847.16  13756.35
# 2        1.604466e+09  2020-11-04 05-AM  BTCUSD  13905.82  13939.55  13793.06
# 3        1.604462e+09  2020-11-04 04-AM  BTCUSD  13913.41  13927.00  13842.00
# 4        1.604459e+09  2020-11-04 03-AM  BTCUSD  13758.26  13965.24  13758.26
# ...               ...               ...     ...       ...       ...       ...
# 29320    1.498921e+09  2017-07-01 03-PM  BTCUSD   2459.35   2475.00   2450.00
# 29321    1.498918e+09  2017-07-01 02-PM  BTCUSD   2454.43   2473.93   2450.83
# 29322    1.498914e+09  2017-07-01 01-PM  BTCUSD   2488.43   2488.43   2454.40
# 29323    1.498910e+09  2017-07-01 12-PM  BTCUSD   2509.17   2512.87   2484.99
# 29324    1.498907e+09  2017-07-01 11-AM  BTCUSD   2505.56   2513.38   2495.12
#
# ...

# %%
df['datetime'] = pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')
df.set_index('datetime',inplace=True)

plt.plot(df['Close'])
plt.show()
